# %%
import sys
sys.path.append(r"C:\Users\kapil\OneDrive\Desktop\Multimodal Medical Report Analyzer")

# %%
from src.table_extraction import extract_pdf_table, save_table_outputs

pdf_path = r'C:\Users\kapil\OneDrive\Desktop\Multimodal Medical Report Analyzer\data\medical_report_table.pdf'
df = extract_pdf_table(pdf_path)
save_table_outputs(df, pdf_path)
# Out:
# Detected: IMAGE PDF (needs OCR)
# Results saved to: C:\Users\kapil\OneDrive\Desktop\Multimodal Medical Report Analyzer\data\medical_report_table_table.csv and C:\Users\kapil\OneDrive\Desktop\Multimodal Medical Report Analyzer\data\medical_report_table_table.json
# ('C:\\Users\\kapil\\OneDrive\\Desktop\\Multimodal Medical Report Analyzer\\data\\medical_report_table_table.csv',
#  'C:\\Users\\kapil\\OneDrive\\Desktop\\Multimodal Medical Report Analyzer\\data\\medical_report_table_table.json')

# %% [markdown]
# # This is working well
# End of code
